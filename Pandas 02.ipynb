# %% [markdown]
# # 폰트 확인

# %%
# from matplotlib import font_manager

# font_manager.fontManager.ttflist

# %% [markdown]
# # 초기화 코드

# %%
# %matplotlib inline

from matplotlib import rc
import numpy as np
import pandas as pd

rc('font', family='Malgun Gothic')  # 윈도우
# rc('font', family='AppleGothic')  # 맥

# %% [markdown]
# # 데이터를 가져오기

# %%
song_df = pd.read_pickle('멜론-차트.pickle')
print(song_df.shape)
song_df.head()
# Out:
# (100, 7)
#          순위                              앨범  \
# 곡일련번호
# 31709523  1                       사춘기집Ⅰ 꽃기운
# 31717822  2                  KILL THIS LOVE
# 31688205  3               사계 (Four Seasons)
# 31709524  4                       사춘기집Ⅰ 꽃기운
# 31706215  5  사월, 그리고 꽃 - The 1st Mini Album
#
#                                            곡명            가수  \
# 곡일련번호
# 31709523                                나만, 봄        볼빨간사춘기
# 31717822                       Kill This Love     BLACKPINK
# 31688205                    사계 (Four Seasons)  태연 (TAEYEON)
# 31709524                             별 보러 갈래?        볼빨간사춘기
# 31706215  사월이 지나면 우리 헤어져요 (Beautiful goodbye)      첸 (CHEN)
#
#                                                    커버이미지_주소     좋아요  test
# 곡일련번호
# 31709523  https://cdnimg.melon.co.kr/cm/album/images/102...   67656     0
# 31717822  https://cdnimg.melon.co.kr/cm/album/images/102...   47994     1
# 31688205  https://cdnimg.melon.co.kr/cm/album/images/102...  115426     2
# ...

# %% [markdown]
# # 간단한 시각화

# %%
song_df['좋아요'][:20]
# Out:
# 곡일련번호
# 31709523     67656
# 31717822     47994
# 31688205    115426
# 31709524     36927
# 31706215     86810
# 31684634     71774
# 31684636     61903
# 31524320    129470
# 31674786     88890
# 31532656    171916
# 31663597     70513
# 31668491     55447
# 31606729     95359
# 31658897     79061
# 31699965     39870
# 31666417     78497
# 31706346     38984
# 31608765     99026
# 31677966     38922
# 31532643    122677
# Name: 좋아요, dtype: int64

# %%
song_df['좋아요'][:20].plot(kind='bar', grid=True, figsize=(15, 5), rot=45,
                      title="멜론 TOP20의 좋아요 그래트")

# %%
song_df['가수'][-20:].value_counts().plot(kind='bar', figsize=(12, 3))

# %%
song_df.plot(x='가수', y='좋아요', kind='bar')

# %% [markdown]
# # 행과 열의 데이터 추가/변경/삭제

# %%
song_df.columns
# Out:
# Index(['순위', '앨범', '곡명', '가수', '커버이미지_주소', '좋아요', 'test'], dtype='object')

# %%
song_df.shape
# Out:
# (100, 7)

# %%
song_df['가수'].size
# Out:
# 100

# %%
song_df['test2'] = 10  # 단일값 = Scalar
song_df.head()
# Out:
#          순위                              앨범  \
# 곡일련번호
# 31709523  1                       사춘기집Ⅰ 꽃기운
# 31717822  2                  KILL THIS LOVE
# 31688205  3               사계 (Four Seasons)
# 31709524  4                       사춘기집Ⅰ 꽃기운
# 31706215  5  사월, 그리고 꽃 - The 1st Mini Album
#
#                                            곡명            가수  \
# 곡일련번호
# 31709523                                나만, 봄        볼빨간사춘기
# 31717822                       Kill This Love     BLACKPINK
# 31688205                    사계 (Four Seasons)  태연 (TAEYEON)
# 31709524                             별 보러 갈래?        볼빨간사춘기
# 31706215  사월이 지나면 우리 헤어져요 (Beautiful goodbye)      첸 (CHEN)
#
#                                                    커버이미지_주소     좋아요  test  \
# 곡일련번호
# 31709523  https://cdnimg.melon.co.kr/cm/album/images/102...   67656     0
# 31717822  https://cdnimg.melon.co.kr/cm/album/images/102...   47994     1
# 31688205  https://cdnimg.melon.co.kr/cm/album/images/102...  115426     2
# ...

# %%
song_df['test2'] = range(100, 200)
song_df.head()
# Out:
#          순위                              앨범  \
# 곡일련번호
# 31709523  1                       사춘기집Ⅰ 꽃기운
# 31717822  2                  KILL THIS LOVE
# 31688205  3               사계 (Four Seasons)
# 31709524  4                       사춘기집Ⅰ 꽃기운
# 31706215  5  사월, 그리고 꽃 - The 1st Mini Album
#
#                                            곡명            가수  \
# 곡일련번호
# 31709523                                나만, 봄        볼빨간사춘기
# 31717822                       Kill This Love     BLACKPINK
# 31688205                    사계 (Four Seasons)  태연 (TAEYEON)
# 31709524                             별 보러 갈래?        볼빨간사춘기
# 31706215  사월이 지나면 우리 헤어져요 (Beautiful goodbye)      첸 (CHEN)
#
#                                                    커버이미지_주소     좋아요  test  \
# 곡일련번호
# 31709523  https://cdnimg.melon.co.kr/cm/album/images/102...   67656     0
# 31717822  https://cdnimg.melon.co.kr/cm/album/images/102...   47994     1
# 31688205  https://cdnimg.melon.co.kr/cm/album/images/102...  115426     2
# ...

# %% [markdown]
# ## df1 + df2

# %%
df1 = pd.DataFrame([
    [1, 2, 3],
    [4, 5, 6],
])
df1
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
df2 = pd.DataFrame([
    [4, 5, 6],
])
df2
# Out:
#    0  1  2
# 0  4  5  6

# %%
df1 + df2
# Out:
#      0    1    2
# 0  5.0  7.0  9.0
# 1  NaN  NaN  NaN

# %%
np.nan
# Out:
# nan

# %%
df3 = pd.DataFrame([
    [11, 12, 13],
])
df3
# Out:
#     0   1   2
# 0  11  12  13

# %%
df2
# Out:
#    0  1  2
# 0  4  5  6

# %%
df2.append(df3)
# Out:
#     0   1   2
# 0   4   5   6
# 0  11  12  13

# %%
df1 + df2.append(df3)
# Out:
#       0     1     2
# 0   5.0   7.0   9.0
# 0  12.0  14.0  16.0
# 1   NaN   NaN   NaN

# %%
df4 = df2.append(df3, ignore_index=True)
df4
# Out:
#     0   1   2
# 0   4   5   6
# 1  11  12  13

# %%
df1 + df4
# Out:
#     0   1   2
# 0   5   7   9
# 1  15  17  19

# %%
song_df1 = song_df.iloc[:25]
song_df2 = song_df.iloc[25:50]
song_df3 = song_df.iloc[50:75]
song_df4 = song_df.iloc[75:]

# %%
song_df1.append(song_df2)  # 2개 DataFrame간의 처리
# Out:
#           순위                                      앨범  \
# 곡일련번호
# 31709523   1                               사춘기집Ⅰ 꽃기운
# 31717822   2                          KILL THIS LOVE
# 31688205   3                       사계 (Four Seasons)
# 31709524   4                               사춘기집Ⅰ 꽃기운
# 31706215   5          사월, 그리고 꽃 - The 1st Mini Album
# 31684634   6                                  장범준 3집
# 31684636   7                                  장범준 3집
# 31524320   8                                 그때가 좋았어
# 31674786   9                       Our love is great
# 31532656  10               FLY HIGH PROJECT #2 `옥탑방`
# 31663597  11                                  Spring
# 31668491  12                              White Wind
# 31606729  13                          IT`z Different
# 31658897  14                 sleepless in __________
# 31699965  15                   진심이 담긴 노래 (True Song)
# 31666417  16                                      전설
# ...

# %%
song_df_list = [
    song_df1,
    song_df3,
    song_df4,
    song_df2,
]

merged_df = pd.concat(song_df_list)
merged_df['순위'] = merged_df['순위'].astype(int)
merged_df.sort_values('순위')
# Out:
#            순위                                       앨범  \
# 곡일련번호
# 31709523    1                                사춘기집Ⅰ 꽃기운
# 31717822    2                           KILL THIS LOVE
# 31688205    3                        사계 (Four Seasons)
# 31709524    4                                사춘기집Ⅰ 꽃기운
# 31706215    5           사월, 그리고 꽃 - The 1st Mini Album
# 31684634    6                                   장범준 3집
# 31684636    7                                   장범준 3집
# 31524320    8                                  그때가 좋았어
# 31674786    9                        Our love is great
# 31532656   10                FLY HIGH PROJECT #2 `옥탑방`
# 31663597   11                                   Spring
# 31668491   12                               White Wind
# 31606729   13                           IT`z Different
# 31658897   14                  sleepless in __________
# 31699965   15                    진심이 담긴 노래 (True Song)
# 31666417   16                                       전설
# ...

# %%
merged_df.columns
# Out:
# Index(['순위', '앨범', '곡명', '가수', '커버이미지_주소', '좋아요', 'test'], dtype='object')

# %%
merged_df = merged_df.drop(columns='test')
# merged_df = merged_df.drop(axis=1, labels='test')
merged_df.head()
# Out:
#           순위                              앨범  \
# 곡일련번호
# 31709523   1                       사춘기집Ⅰ 꽃기운
# 31717822   2                  KILL THIS LOVE
# 31688205   3               사계 (Four Seasons)
# 31709524   4                       사춘기집Ⅰ 꽃기운
# 31706215   5  사월, 그리고 꽃 - The 1st Mini Album
#
#                                            곡명            가수  \
# 곡일련번호
# 31709523                                나만, 봄        볼빨간사춘기
# 31717822                       Kill This Love     BLACKPINK
# 31688205                    사계 (Four Seasons)  태연 (TAEYEON)
# 31709524                             별 보러 갈래?        볼빨간사춘기
# 31706215  사월이 지나면 우리 헤어져요 (Beautiful goodbye)      첸 (CHEN)
#
#                                                    커버이미지_주소     좋아요
# 곡일련번호
# 31709523  https://cdnimg.melon.co.kr/cm/album/images/102...   67656
# 31717822  https://cdnimg.melon.co.kr/cm/album/images/102...   47994
# 31688205  https://cdnimg.melon.co.kr/cm/album/images/102...  115426
# ...

# %%
# merged_df.drop(axis='columns', labels=['앨범', '커버이미지_주소'])

names = ['좋아요', '순위', '곡명', '가수']
merged_df[names].head()
# Out:
#              좋아요  순위                                   곡명            가수
# 곡일련번호
# 31709523   67656   1                                나만, 봄        볼빨간사춘기
# 31717822   47994   2                       Kill This Love     BLACKPINK
# 31688205  115426   3                    사계 (Four Seasons)  태연 (TAEYEON)
# 31709524   36927   4                             별 보러 갈래?        볼빨간사춘기
# 31706215   86810   5  사월이 지나면 우리 헤어져요 (Beautiful goodbye)      첸 (CHEN)

# %%
'%06d' % 10
# Out:
# '000010'

# %%
'{0:06d} {1} {0}'.format(10, 20, 30)
# Out:
# '000010 20 10'

# %%
def fn(value):
    return '{:06d}'.format(value)
merged_df['순위'].apply(fn)

# merged_df['순위'].astype(int)
def fn(value):
    return int(value)
merged_df['순위'].apply(fn).head()
# Out:
# 곡일련번호
# 31709523    1
# 31717822    2
# 31688205    3
# 31709524    4
# 31706215    5
# Name: 순위, dtype: int64

# %% [markdown]
# # 엑셀 파일 합치기

# %%
import os

# data 디렉토리가 없으면, 생성을 합니다.
if not os.path.exists('data'):
    os.makedirs('data')

# %%
# 엑셀 파일 생성
song_df1.to_excel('data/song_df1.xlsx')
song_df2.to_excel('data/song_df2.xlsx')
song_df3.to_excel('data/song_df3.xlsx')
song_df4.to_excel('data/song_df4.xlsx')

# %%
# df_list = [
#     pd.read_excel('data/song_df1.xlsx', sheet_name=0, index_col='곡일련번호'),
#     pd.read_excel('data/song_df2.xlsx', sheet_name=0, index_col='곡일련번호'),
#     pd.read_excel('data/song_df3.xlsx', sheet_name=0, index_col='곡일련번호'),
#     pd.read_excel('data/song_df4.xlsx', sheet_name=0, index_col='곡일련번호'),
# ]
# pd.concat(df_list)

# %%
import pathlib

# %%
df_list = []
for path in pathlib.Path('.').glob('**/song_df*.xlsx'):
    print(path)
    df = pd.read_excel(path, sheet_name=0, index_col='곡일련번호')
    df_list.append(df)

pd.concat(df_list)
# Out:
# data/song_df3.xlsx
# data/song_df2.xlsx
# data/song_df4.xlsx
# data/song_df1.xlsx
#            순위                                   앨범  \
# 곡일련번호
# 31567235   51                              7 rings
# 31324607   52                         사랑에 연습이 있었다면
# 31717823   53                       KILL THIS LOVE
# 31085237   54               LOVE YOURSELF 轉 `Tear`
# 31402611   55                        thank u, next
# 31706216   56       사월, 그리고 꽃 - The 1st Mini Album
# 31709525   57                            사춘기집Ⅰ 꽃기운
# 31346009   58                                   삐삐
# 31448480   59                                   XX
# 31356458   60                                   고백
# 31706217   61       사월, 그리고 꽃 - The 1st Mini Album
# 31674782   62                                   혼자
# 31706218   63       사월, 그리고 꽃 - The 1st Mini Album
# 31403156   64                                    별
# 31133898   65                           THIS IS US
# 31597986   66                    진심이 닿다 OST Part.1
# ...

# %% [markdown]
# # 문자열을 입맛대로 처리하기

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 31709523 to 31131273
# Data columns (total 7 columns):
# 순위          100 non-null object
# 앨범          100 non-null object
# 곡명          100 non-null object
# 가수          100 non-null object
# 커버이미지_주소    100 non-null object
# 좋아요         100 non-null int64
# test        100 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 11.2+ KB

# %%
song_df.describe()
# Out:
#                  좋아요        test
# count     100.000000  100.000000
# mean   101976.810000   49.500000
# std     82728.582079   29.011492
# min      7531.000000    0.000000
# 25%     37435.500000   24.750000
# 50%     86481.500000   49.500000
# 75%    139914.500000   74.250000
# max    395365.000000   99.000000

# %%
# def fn(value): return value[-1]
# song_df['곡명'].apply(fn)

song_df['곡명'].str[:3].head()
# Out:
# 곡일련번호
# 31709523    나만,
# 31717822    Kil
# 31688205    사계
# 31709524    별 보
# 31706215    사월이
# Name: 곡명, dtype: object

# %%
"a,b,c,d,e".split(",", 1)

print('Python,"Hello,World",Pandas'.split(",", 1))
print('Python,"Hello,World",Pandas'.rsplit(",", 1))
# Out:
# ['Python', '"Hello,World",Pandas']
# ['Python,"Hello,World"', 'Pandas']

# %%
song_df['곡명'].head()
# Out:
# 곡일련번호
# 31709523                                  나만, 봄
# 31717822                         Kill This Love
# 31688205                      사계 (Four Seasons)
# 31709524                               별 보러 갈래?
# 31706215    사월이 지나면 우리 헤어져요 (Beautiful goodbye)
# Name: 곡명, dtype: object

# %%
song_df['곡명'].str[1:].head()
# song_df['곡명'].str.slice(1)
# Out:
# 곡일련번호
# 31709523                                  만, 봄
# 31717822                         ill This Love
# 31688205                      계 (Four Seasons)
# 31709524                                보러 갈래?
# 31706215    월이 지나면 우리 헤어져요 (Beautiful goodbye)
# Name: 곡명, dtype: object

# %%
song_df['가수_글자수'] = song_df['가수'].apply(lambda 가수: len(가수))
song_df[['가수', '가수_글자수']].head()
# Out:
#                     가수  가수_글자수
# 곡일련번호
# 31709523        볼빨간사춘기       6
# 31717822     BLACKPINK       9
# 31688205  태연 (TAEYEON)      12
# 31709524        볼빨간사춘기       6
# 31706215      첸 (CHEN)       8
